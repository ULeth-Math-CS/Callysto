# %% [markdown]
# ## Changes
#
#  * Capitalized section headers.
#  * Fixed a lot of punctuation errors.
#  * Fixed consistency of verb tenses ("3 slices are left" vs. "3 slices were left").
#  * Fixed broken images. Changed references to 'assets' folder to 'images'.
#  * Increased size of parentheses in LaTeX equation.
#  * Changed instances of "let us" to "let's" for consistency.
#  * Changed "real number" to simply "number". A student who is just learning about fractions won't know about real numbers. Real numbers are introduced in later grade levels.
#
# ## Suggestions
#
#  * The learning outcome for the notebook was to "develop a visual understanding of fraction addition," but you used very few visualizations except at the end.
#  * Insert some visualizations in the early sections.
#     * Show how we can represent, say, the fraction 2/3 by cutting a rectangle into 3 pieces and coloring in 2. This is consistent with the rectangles in the animation in the last section.
#     * <s>Or where you reference eating 3/8 of a pizza, a visualization of a pizza with 3/8 eaten.</s>
#  *<s> 'numDenom.png' should be placed in the introduction where you first review the terms numerator and denominator</s>
#  * <s>Include pictures with your pizza examples. This would also reinforce the idea that students should draw pictures to help solve math problems.</s>
#  * Online calculators rate the difficulty of different sections of this notebook anywhere between a 7th and 12th grade reading level.
#     * There are a lot of long compound sentences with "and" that could be broken into two sentences.
#     * There are a lot of parenthetical that could be worked into the paragraphs differently.
#  * <s>Grammar errors in all of Pixel Cat's speech bubbles. These are my suggested edits:</s>
#
# <s> > If we count the coloured sections they equal to the numerators and if we count all the sections they equal to the denominators. Let's see what happens when we click on combine!
#
# The number of sections is equal to the denominators. The numbers of coloured sections are equal to the numerators. Let's see what happens when we click on combine!
#
# > Looks like we have common denominators, that's lucky! I bet if we count all the coloured sections from the new box we will get the numerator to our answer!
#
# Looks like we have common denominators. That's lucky! I bet if we count all the coloured sections from the new box, we will get the numerator to our answer.
#
# > It combined the two boxes together, neat!! It looks like the new combined box might be the answer to our addition but the sections are different sizes.
#
# It combined the two boxes together. Neat!
#
# > Let's play around with the multiply buttons and see if our sections change in size?
#
# Let's play around with the multiply buttons and see if our sections change in size!
#
# > Nice our assumbtion was correct! Maybe if we find a common denominator then all the sections will have the same size.
#
# Nice! Our assumption was correct! Maybe if we find a common denominator, then all the sections will have the same size.
#
# > Well done, now all the sections are equal in size. I bet if we count all the coloured sections now we will get the numerator to our answer."
#
# Well done! Now all the sections are equal in size. I bet if we count all the coloured sections now, we will get the correct numerator.
#
# > Meow
#
# Meow!</s>
#
#  * A few excerpts that I think need to be reworded or expanded upon:
#
# > <s>Still don't believe me?</s>
#
# <s>This sounds awkward. This is the only reference to "me" or "I" in the notebook. Believe you about what? You make a lot of statements in the preceding text and the last statement is that a calculator evaluates both 1/2 and 16/32 as 0.5. Why wouldn't they believe that?</s>
#
# ><s> What is really happening is that the bottom number (the denominator) tells you how many equal parts the *object* is divided into, and the top number (the numerator) tells you how many of these equal parts we actually have.</s>
#
# <s>Maybe make the point afterwards that if you cut a pizza into 2 pieces and take 1, or if you cut a pizza into 32 pieces and take 16, you took the same amount of pizza: half of it.</s>
#
# > <s>Now that we have a better understanding of how to add fractions with like denominators, let’s look at our pizza example.</s>
#
# <s>The reader just went through a review section on fractions and watched a YouTube video and has probably forgotten the example by now.
# You should repeat the example so that the reader doesn't have to scroll up to remember what the scenario is.</s>
