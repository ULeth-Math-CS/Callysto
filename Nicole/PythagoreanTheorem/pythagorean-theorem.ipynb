# %% [markdown]
# ![logo](https://callysto.ca/wp-content/uploads/2018/06/Callysto_Notebook-Banner_Top_06.06.18.jpg)

# %% [markdown]
# pg 31 in math makes sense grade 8

# %%
# %%html
#
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
from IPython.display import Image

# %% [markdown]
# # Pythagorean Theorem
#
# ##### Grade 8 curriculum
# This jupyter notebook will cover the pythagorean theorem, including how it was found and its applications.
#
# **Note:** You should have a solid understanding of square roots and exponents with the power of 2 before moving on to this notebook. This notebook assumes you know these concepts well.
#
# ## Introduction
#
# Say you have 2 sides of a right angle triangle and are trying to figure out the third. How can we do this? Thankfully that's where the pythagorean theorem comes in!
#
# #### Terminology
#
# **Hypotenuse:** the longest side of a triangle
#
# **legs:** the other two sides of a triangle that are not the hypotenuse
#
# #### What is this theorem?
#
# When you draw a right angle triangle with a square on each side like this:

# %%
Image('pythagoreanTriangle.png',width=400,height=600)

# %% [markdown]
# There's a relationship between the areas of the squares. You should notice that the areas of the squares on the two legs added together are equal to the area of the largest square on the hypotenuse. In this example, the area of the red square is 9
# This relationship actually works for all right angle triangles!
#
# **Fact:** The Pythagorean Theorem is named for the Greek mathematician, Pythagoras.

# %% [markdown]
# ![logo](https://callysto.ca/wp-content/uploads/2018/07/Callysto-Notebook-Banner_Bottom_07.30.18.jpg)
